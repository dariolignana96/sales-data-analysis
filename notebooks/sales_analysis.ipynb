# %%
# Sales Data Analysis
# Analisi esplorativa di dati di vendita in Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
data = {
    'Product': np.random.choice(['A', 'B', 'C'], 100),
    'Sales': np.random.randint(100, 5000, 100),
    'Quantity': np.random.randint(1, 50, 100),
    'Region': np.random.choice(['North', 'South', 'East', 'West'], 100)
}
df = pd.DataFrame(data)
df.to_csv('../data/sales_data.csv', index=False)

# %%
print("=== DATASET OVERVIEW ===")
print(f"Shape: {df.shape}")
df.head()
# Out:
# === DATASET OVERVIEW ===
# Shape: (100, 4)
#   Product  Sales  Quantity Region
# 0       C   2127        48  South
# 1       A   2795        16  North
# 2       C   1595        33  South
# 3       C    491         9  North
# 4       A   4614         6   West

# %%
df.describe()
# Out:
#              Sales    Quantity
# count   100.000000  100.000000
# mean   2716.560000   25.490000
# std    1346.259744   14.075191
# min     297.000000    1.000000
# 25%    1659.750000   16.000000
# 50%    2812.000000   25.500000
# 75%    3731.500000   36.000000
# max    4991.000000   49.000000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product', y='Sales', data=df)
plt.title('Vendite medie per Prodotto')
plt.show()

# %%
# Questo notebook mostra la pipeline base per l'analisi esplorativa di dati di vendita. Si parte dalla generazione/lettura dati, si esplora la struttura del dataset, si calcolano statistiche descrittive e si producono visualizzazioni base.
